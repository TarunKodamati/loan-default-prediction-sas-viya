# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, f1_score, confusion_matrix, roc_auc_score, classification_report
from sklearn.metrics import mean_squared_error

# %%
lona_17=pd.read_excel('/content/drive/MyDrive/Colab/loan project/loan_2017.xlsx')

# %%
loan_18=pd.read_excel('/content/drive/MyDrive/Colab/loan project/loan_2018.xlsx')

# %%
loan_17=lona_17

# %%
loan_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88341 entries, 0 to 88340
# Data columns (total 98 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              88341 non-null  int64
#  1   loan_amnt                       88341 non-null  int64
#  2   term_months                     88341 non-null  int64
#  3   installment                     88341 non-null  float64
#  4   sub_grade                       88341 non-null  object
#  5   emp_length                      82254 non-null  float64
#  6   home_ownership                  88341 non-null  object
#  7   annual_inc                      88341 non-null  float64
#  8   verification_status             88341 non-null  object
#  9   loan_status                     88341 non-null  int64
#  10  purpose                         88341 non-null  object
#  11  addr_state                      88341 non-null  object
# ...

# %%
loan_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32834 entries, 0 to 32833
# Data columns (total 98 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              32834 non-null  int64
#  1   loan_amnt                       32834 non-null  int64
#  2   term_months                     32834 non-null  int64
#  3   installment                     32834 non-null  float64
#  4   sub_grade                       32834 non-null  object
#  5   emp_length                      29968 non-null  float64
#  6   home_ownership                  32834 non-null  object
#  7   annual_inc                      32834 non-null  float64
#  8   verification_status             32834 non-null  object
#  9   loan_status                     32834 non-null  int64
#  10  purpose                         32834 non-null  object
#  11  addr_state                      32834 non-null  object
# ...

# %%
loan_17.describe().T
# Out:
#                           count          mean           std        min  \
# id                      88341.0  1.117999e+08  4.842603e+06  687119.00
# loan_amnt               88341.0  1.408882e+04  9.390212e+03    1000.00
# term_months             88341.0  4.177499e+01  1.025916e+01      36.00
# installment             88341.0  4.341615e+02  2.885249e+02      30.12
# emp_length              82254.0  5.798599e+00  3.789068e+00       0.00
# ...                         ...           ...           ...        ...
# fico_score              88341.0  7.003709e+02  3.401585e+01     662.00
# last_fico_score         88341.0  6.652547e+02  1.063408e+02     249.50
# earliest_cr_line_year   88341.0  2.001093e+03  7.903732e+00    1969.00
# earliest_cr_line_month  88341.0  6.736080e+00  3.371426e+00       1.00
# credit_history_years    88341.0  1.539825e+01  7.887489e+00     -51.00
#
#                                  25%           50%           75%           max
# ...

# %%
loan_18.describe().T
# Out:
#                           count          mean           std          min  \
# id                      32834.0  1.313867e+08  4.745877e+06  70102325.00
# loan_amnt               32834.0  1.501008e+04  1.010961e+04      1000.00
# term_months             32834.0  4.243747e+01  1.063305e+01        36.00
# installment             32834.0  4.485800e+02  2.929118e+02        30.12
# emp_length              29968.0  5.916478e+00  3.722182e+00         0.00
# ...                         ...           ...           ...          ...
# fico_score              32834.0  7.104456e+02  3.794853e+01       662.00
# last_fico_score         32834.0  6.869126e+02  9.563176e+01         0.00
# earliest_cr_line_year   32834.0  2.001899e+03  7.958023e+00      1969.00
# earliest_cr_line_month  32834.0  6.743985e+00  3.368946e+00         1.00
# credit_history_years    32834.0  1.536328e+01  7.940334e+00       -50.00
#
#                                  25%           50%           75%           max
# ...

# %%
loan_17["credit_history_years"].value_counts()
# Out:
# credit_history_years
# 12    7690
# 11    6953
# 10    6051
# 13    5711
# 14    5678
# 15    4950
# 16    4837
# 17    3745
# 18    3552
# 9     3294
# 19    2923
# 20    2877
# 21    2426
# 8     2335
# 22    2259
# 6     2020
# 23    1991
# 7     1943
# 4     1851
# 5     1818
# 24    1558
# 3     1413
# 27    1203
# 26    1194
# 28    1100
# 25    1074
# 30     868
# 29     812
# 31     672
# 32     617
# 33     449
# 34     413
# 35     312
# 36     232
# 38     220
# 39     203
# 37     191
# 40     175
# 41     131
# 44     106
# 42     103
# 43      81
# 47      68
# 48      56
# 46      54
# 45      53
# 50      32
# 51      30
# 49      17
# Name: count, dtype: int64

# %%
loan_18['credit_history_years'] = loan_18['credit_history_years'].abs()
loan_17['credit_history_years'] = loan_17['credit_history_years'].abs()

# %%
loan_18["dti"].describe()
# Out:
# count    32738.000000
# mean        18.577039
# std         18.311968
# min          0.000000
# 25%         10.430000
# 50%         16.830000
# 75%         24.020000
# max        999.000000
# Name: dti, dtype: float64

# %%
loan=pd.read_excel('/content/drive/MyDrive/Colab/loan project/loan5.xlsx')

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121175 entries, 0 to 121174
# Columns: 119 entries, id to credit_history_years
# dtypes: float64(50), int64(56), object(13)
# memory usage: 110.0+ MB

# %%
loan
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 121170  102395624      35000   60 months     13.99       814.21        C3
# 121171  102426796      12000   60 months     28.69       378.65        F1
# 121172  102556443      24000   60 months     23.99       690.30        E2
# 121173  102196576       6000   36 months     11.44       197.69        B4
# 121174   99799684      30000   60 months     25.49       889.18        E4
#
#                     emp_title  emp_length home_ownership  annual_inc  ...  \
# ...

# %%
loan=loan[loan["earliest_cr_line_year"]<2016]

# %%
loan
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 121170  102395624      35000   60 months     13.99       814.21        C3
# 121171  102426796      12000   60 months     28.69       378.65        F1
# 121172  102556443      24000   60 months     23.99       690.30        E2
# 121173  102196576       6000   36 months     11.44       197.69        B4
# 121174   99799684      30000   60 months     25.49       889.18        E4
#
#                     emp_title  emp_length home_ownership  annual_inc  ...  \
# ...

# %%
loan["earliest_cr_line_year"].value_counts()
# Out:
# earliest_cr_line_year
# 2005    9538
# 2006    9218
# 2004    9192
# 2003    8113
# 2007    7130
# 2002    6923
# 2001    6357
# 2000    5699
# 1999    5118
# 1998    4075
# 2008    4051
# 1997    3772
# 1996    3590
# 1995    3359
# 2011    2864
# 2010    2848
# 1994    2788
# 2009    2714
# 2012    2633
# 2013    2407
# 1993    2373
# 1990    1687
# 1992    1635
# 1991    1570
# 1989    1534
# 2014    1310
# 1987    1169
# 1988    1157
# 1986    1000
# 1985     847
# 1984     753
# 1983     614
# 1982     496
# 1981     317
# 1979     293
# 1978     281
# 1980     268
# 1977     234
# 1976     193
# 1975     150
# 2015     142
# 1974     126
# 1973     120
# 1972      99
# 1969      79
# 1970      62
# 1971      55
# Name: count, dtype: int64

# %%
loan=loan[loan["last_fico_score"]>0]

# %%
loan
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 121170  102395624      35000   60 months     13.99       814.21        C3
# 121171  102426796      12000   60 months     28.69       378.65        F1
# 121172  102556443      24000   60 months     23.99       690.30        E2
# 121173  102196576       6000   36 months     11.44       197.69        B4
# 121174   99799684      30000   60 months     25.49       889.18        E4
#
#                     emp_title  emp_length home_ownership  annual_inc  ...  \
# ...

# %%
loan["last_fico_score"].min()
# Out:
# 249.5

# %%
loan=loan[loan["annual_inc"]>0]

# %%
loan=loan[loan["dti"]<=100]

# %%
loan
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 121170  102395624      35000   60 months     13.99       814.21        C3
# 121171  102426796      12000   60 months     28.69       378.65        F1
# 121172  102556443      24000   60 months     23.99       690.30        E2
# 121173  102196576       6000   36 months     11.44       197.69        B4
# 121174   99799684      30000   60 months     25.49       889.18        E4
#
#                     emp_title  emp_length home_ownership  annual_inc  ...  \
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120509 entries, 0 to 121174
# Columns: 119 entries, id to credit_history_years
# dtypes: float64(50), int64(56), object(13)
# memory usage: 110.3+ MB

# %%
loan.columns
# Out:
# Index(['id', 'loan_amnt', 'term', 'int_rate', 'installment', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        ...
#        'settlement_amount', 'settlement_percentage', 'settlement_term',
#        'issue_year', 'issue_month', 'fico_score', 'last_fico_score',
#        'earliest_cr_line_year', 'earliest_cr_line_month',
#        'credit_history_years'],
#       dtype='object', length=119)

# %%
loan=loan[loan["revol_util"]<=100]

# %%
loan["pct_tl_nvr_dlq"].value_counts()
# Out:
# pct_tl_nvr_dlq
# 100.0    60863
# 90.0      1482
# 90.9      1348
# 92.3      1346
# 91.7      1322
#          ...
# 42.4         1
# 32.3         1
# 79.7         1
# 64.4         1
# 55.8         1
# Name: count, Length: 491, dtype: int64

# %%
loan.iloc[:,100:200]
# Out:
#         sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                      NaN                  NaN                    NaN
# 1                      NaN                  NaN                    NaN
# 2                      NaN                  NaN                    NaN
# 3                      NaN                  NaN                    NaN
# 4                      NaN                  NaN                    NaN
# ...                    ...                  ...                    ...
# 121170                 NaN                  NaN                    NaN
# 121171                 NaN                  NaN                    NaN
# 121172                 NaN                  NaN                    NaN
# 121173                 NaN                  NaN                    NaN
# 121174                 NaN                  NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# ...

# %%
columns=["annual_inc_joint","dti_joint","verification_status_joint","revol_bal_joint","sec_app_fico_range_low","sec_app_fico_range_high","sec_app_inq_last_6mths",
         "sec_app_mort_acc","sec_app_open_acc","sec_app_revol_util","sec_app_open_act_il","sec_app_num_rev_accts","sec_app_chargeoff_within_12_mths",
         "sec_app_collections_12_mths_ex_med","sec_app_mths_since_last_major_derog","settlement_status","settlement_amount","settlement_percentage",
         "settlement_term"]

# %%
loan.drop(columns=columns,inplace=True)
# Out:
# /tmp/ipykernel_310/4249868854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan.drop(columns=columns,inplace=True)

# %%
loan
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 121170  102395624      35000   60 months     13.99       814.21        C3
# 121171  102426796      12000   60 months     28.69       378.65        F1
# 121172  102556443      24000   60 months     23.99       690.30        E2
# 121173  102196576       6000   36 months     11.44       197.69        B4
# 121174   99799684      30000   60 months     25.49       889.18        E4
#
#                     emp_title  emp_length home_ownership  annual_inc  ...  \
# ...

# %%
loan["loan_status"].value_counts(normalize=True)
# Out:
# loan_status
# 0    0.781751
# 1    0.218249
# Name: proportion, dtype: float64

# %%
loan_2017 = loan[loan["issue_year"] == 2017]
loan_2018 = loan[loan["issue_year"] == 2018]

# %%
loan.to_excel("/content/drive/MyDrive/Colab/loan project/loan5.xlsx",index=False)

# %%
loan_2017
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_909/3877727230.py in <cell line: 0>()
# ----> 1 loan_2017
#
# NameError: name 'loan_2017' is not defined

# %%
loan=pd.read_excel("/content/drive/MyDrive/Colab/loan project/loan5.xlsx")

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120092 entries, 0 to 120091
# Data columns (total 99 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              120092 non-null  int64
#  1   loan_amnt                       120092 non-null  int64
#  2   term                            120092 non-null  object
#  3   int_rate                        120092 non-null  float64
#  4   installment                     120092 non-null  float64
#  5   sub_grade                       120092 non-null  object
#  6   emp_length                      111581 non-null  float64
#  7   home_ownership                  120092 non-null  object
#  8   annual_inc                      120092 non-null  float64
#  9   verification_status             120092 non-null  object
#  10  loan_status                     120092 non-null  int64
#  11  Purpose                         120092 non-null  object
# ...

# %%
loan1.to_csv("/content/drive/MyDrive/Colab/loan project/loan5.csv",index=False)

# %%
loan1 = pd.read_csv("/content/drive/MyDrive/Colab/loan project/loan5.csv")

# %%
loan1["acc_now_delinq"].value_counts()
# Out:
# acc_now_delinq
# 0    119643
# 1       412
# 2        21
# 3         2
# Name: count, dtype: int64

# %%
loan1["inq_last_6mths"].value_counts()
# Out:
# inq_last_6mths
# 0    71988
# 1    32512
# 2    11049
# 3     3471
# 4      773
# 5      299
# Name: count, dtype: int64

# %%
loan1["inq_last_6mths"].value_counts()
# Out:
# inq_last_6mths
# 0    71978
# 1    32510
# 2    11048
# 3     3470
# 4      773
# 5      299
# Name: count, dtype: int64

# %%
loan1 = loan1[~loan1["home_ownership"].isin(["NONE", "ANY"])]

# %%
loan1
# Out:
#                id  loan_amnt        term  int_rate  installment sub_grade  \
# 0       130956066       3000   36 months      7.34        93.10        A4
# 1       130968727       5000   36 months     11.98       166.03        B5
# 2       130910225       7000   36 months     11.98       232.44        B5
# 3       130966492      30000   36 months     21.85      1143.39        D5
# 4       130942737      21000   60 months     20.39       560.94        D4
# ...           ...        ...         ...       ...          ...       ...
# 120087  102395624      35000   60 months     13.99       814.21        C3
# 120088  102426796      12000   60 months     28.69       378.65        F1
# 120089  102556443      24000   60 months     23.99       690.30        E2
# 120090  102196576       6000   36 months     11.44       197.69        B4
# 120091   99799684      30000   60 months     25.49       889.18        E4
#
#         emp_length home_ownership  annual_inc verification_status  ...  \
# ...

# %%
loan1["mths_since_recent_bc"].value_counts(dropna=False)
print("mths_since_recent_bc",loan1["mths_since_recent_bc"].isna().sum())

print("percent_bc_gt_75",loan1["percent_bc_gt_75"].isna().sum())
print("bc_util",loan1["bc_util"].isna().sum())
print("mths_since_rcnt_il",loan1["mths_since_rcnt_il"].isna().sum())
print("mo_sin_old_il_acct",loan1["mo_sin_old_il_acct"].isna().sum())
print("num_tl_120dpd_2m",loan1["num_tl_120dpd_2m"].isna().sum())
print("emp_length",loan1["emp_length"].isna().sum())
print("mths_since_recent_inq",loan1["mths_since_recent_inq"].isna().sum())
print("il_util",loan1["il_util"].isna().sum())
# Out:
# mths_since_recent_bc 1454
# bc_open_to_buy 1549
# percent_bc_gt_75 1552
# bc_util 1605
# mths_since_rcnt_il 3246
# mo_sin_old_il_acct 3246
# num_tl_120dpd_2m 5225
# emp_length 8506
# mths_since_recent_inq 10452
# il_util 16780

# %%
print(loan1["bc_open_to_buy"].value_counts())
loan1["bc_open_to_buy"].isna().sum()
# Out:
# bc_open_to_buy
# 0.0        916
# 2000.0     131
# 5000.0     115
# 500.0      113
# 1000.0     106
#           ...
# 19746.0      1
# 47021.0      1
# 25032.0      1
# 52223.0      1
# 12427.0      1
# Name: count, Length: 37297, dtype: int64
# np.int64(1549)

# %%
loan1["il_util"].value_counts(dropna=False)
# Out:
# il_util
# NaN      16780
# 83.0      2163
# 81.0      2069
# 78.0      2041
# 86.0      1969
#          ...
# 196.0        1
# 182.0        1
# 199.0        1
# 181.0        1
# 176.0        1
# Name: count, Length: 202, dtype: int64

# %%
cols=['il_util',
'mths_since_recent_inq',
'emp_length',
'num_tl_120dpd_2m',
'mo_sin_old_il_acct',
'mths_since_rcnt_il',
'bc_util',
'percent_bc_gt_75',
'bc_open_to_buy',
'mths_since_recent_bc',
'pct_tl_nvr_dlq']
loan1[cols].skew()
# Out:
# il_util                  -0.332471
# mths_since_recent_inq     0.993904
# emp_length               -0.155660
# num_tl_120dpd_2m         46.378270
# mo_sin_old_il_acct        0.304497
# mths_since_rcnt_il        3.734626
# bc_util                  -0.009136
# percent_bc_gt_75          0.616984
# bc_open_to_buy            3.280001
# mths_since_recent_bc      3.944302
# pct_tl_nvr_dlq           -2.345472
# dtype: float64

# %%
import warnings
import pandas as pd
warnings.simplefilter(action='ignore', category=pd.errors.DtypeWarning)

main=pd.read_csv("/content/drive/MyDrive/Colab/loan project/accepted_2007_to_2018Q4.csv")

# %%
main
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29443/1601733163.py in <cell line: 0>()
# ----> 1 main
#
# NameError: name 'main' is not defined
